# %%
# IMPORTS
import pandas as pd
import matplotlib

# %%
# !which python
# Out:
# /home/eidf128/eidf128/nfabrega_big_eidf/.conda/envs/exp_conv_env_2/bin/python

# %%
# IMPORT DATA
DATA_P = "../data/"

# %%
# DATA ANALYSIS
